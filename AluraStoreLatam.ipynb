# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
#instalar biblioteca
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# Debes evaluar información como los ingresos, las categorías más vendidas, las reseñas de los clientes, los productos más vendidos y el envío promedio.
store_labels = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# %% [markdown]
# #1. Análisis de facturación

# %%
total_price_tienda = sum(tienda['Precio'])
total_price_tienda2 = sum(tienda2['Precio'])
total_price_tienda3 = sum(tienda3['Precio'])
total_price_tienda4 = sum(tienda4['Precio'])

print(total_price_tienda, total_price_tienda2, total_price_tienda3, total_price_tienda4)
# Out:
# 1150880400.0 1116343500.0 1098019600.0 1038375700.0

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [total_price_tienda, total_price_tienda2, total_price_tienda3, total_price_tienda4]

plt.figure() #Figura. Puede incluirse el tamaño con figsize
plt.bar(store_labels, data) #El gráfico
plt.title('Ventas por tienda') #El título
ax = plt.subplot() #Axis
ax.set_xticks(store_labels)  #Eje x
ax.set_xticklabels(store_labels) #Etiquetas del eje x
ax.set_xlabel('Tiendas')  #Nombre del eje x
ax.set_ylabel('Ventas')  #Nombre del eje y

plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
category_counts = tienda.groupby('Categoría del Producto').size()
category_counts2 = tienda2.groupby('Categoría del Producto').size()
category_counts3 = tienda3.groupby('Categoría del Producto').size()
category_counts4 = tienda4.groupby('Categoría del Producto').size()
print(category_counts, category_counts2, category_counts3, category_counts4)
# Out:
# Categoría del Producto
# Artículos para el hogar    171
# Deportes y diversión       284
# Electrodomésticos          312
# Electrónicos               448
# Instrumentos musicales     182
# Juguetes                   324
# Libros                     173
# Muebles                    465
# dtype: int64 Categoría del Producto
# Artículos para el hogar    181
# Deportes y diversión       275
# Electrodomésticos          305
# Electrónicos               422
# Instrumentos musicales     224
# Juguetes                   313
# Libros                     197
# Muebles                    442
# dtype: int64 Categoría del Producto
# Artículos para el hogar    177
# Deportes y diversión       277
# Electrodomésticos          278
# Electrónicos               451
# Instrumentos musicales     177
# Juguetes                   315
# Libros                     185
# Muebles                    499
# dtype: int64 Categoría del Producto
# Artículos para el hogar    201
# Deportes y diversión       277
# Electrodomésticos          254
# Electrónicos               451
# Instrumentos musicales     170
# Juguetes                   338
# Libros                     187
# Muebles                    480
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data preparation
categories = category_counts.index  # Product categories['Artículos para el hogar', 'Deportes y diversión', ..]
counts = [category_counts.values, category_counts2.values, category_counts3.values, category_counts4.values]

x = np.arange(len(categories))  # Position of categories
width = 0.2  # Width of each bar

# Create grouped bars
fig, ax = plt.subplots(figsize=(12, 6))
for i in range(len(store_labels)):
    ax.bar(x + i * width, counts[i], width, label=store_labels[i])

# Formatting
ax.set_xlabel('Categoría del Producto')
ax.set_ylabel('Cantidad de Ventas')
ax.set_title('Ventas por Categoría en Diferentes Tiendas')
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels(categories, rotation=45)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
total_price_tienda = sum(tienda['Calificación'])
promedio_calificacion_tienda = total_price_tienda / len(tienda)
total_price_tienda2 = sum(tienda2['Calificación'])
promedio_calificacion_tienda2 = total_price_tienda2 / len(tienda2)
total_price_tienda3 = sum(tienda3['Calificación'])
promedio_calificacion_tienda3 = total_price_tienda3 / len(tienda3)
total_price_tienda4 = sum(tienda4['Calificación'])
promedio_calificacion_tienda4 = total_price_tienda4 / len(tienda4)

print(promedio_calificacion_tienda, promedio_calificacion_tienda2, promedio_calificacion_tienda3, promedio_calificacion_tienda4)
# Out:
# 3.976685036032217 4.037303942348453 4.048325561678677 3.9957591178965224

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [promedio_calificacion_tienda, promedio_calificacion_tienda2, promedio_calificacion_tienda3, promedio_calificacion_tienda4]

plt.figure() #Figura. Puede incluirse el tamaño con figsize
plt.plot(store_labels, data) #El gráfico
plt.title('Promedio de ventas por tienda') #El título
ax = plt.subplot() #Axis
ax.set_xticks(store_labels)  #Eje x
ax.set_xticklabels(store_labels) #Etiquetas del eje x
ax.set_xlabel('Tiendas')  #Nombre del eje x
ax.set_ylabel('Ventas')  #Nombre del eje y

plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
product_counts_tienda = tienda.groupby('Producto').size().sort_values(ascending=False)
product_counts_tienda2 = tienda2.groupby('Producto').size().sort_values(ascending=False)
product_counts_tienda3 = tienda3.groupby('Producto').size().sort_values(ascending=False)
product_counts_tienda4 = tienda4.groupby('Producto').size().sort_values(ascending=False)

print(product_counts_tienda, product_counts_tienda2, product_counts_tienda3, product_counts_tienda4)
# Out:
# Producto
# Armario                        60
# TV LED UHD 4K                  60
# Microondas                     60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Impresora                      54
# Vaso térmico                   54
# Refrigerador                   54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Guitarra eléctrica             47
# Lavadora de ropa               47
# Silla de oficina               46
# Sofá reclinable                46
# Guitarra acústica              46
# Estufa                         45
# Mesa de centro                 44
# Kit de bancas                  44
# Cama box                       44
# Cubo mágico 8x8                44
# Smart TV                       44
# Cama king                      44
# Juego de mesa                  43
# Smartwatch                     43
# Set de ollas                   43
# Dashboards con Power BI        42
# Tablet ABXY                    42
# Balón de voleibol              42
# Sillón                         41
# Iniciando en programación      41
# Set de vasos                   41
# Asistente virtual              40
# Dinosaurio Rex                 40
# Cuerda para saltar             40
# Muñeca bebé                    40
# Mesa de comedor                40
# Ciencia de datos con Python    39
# Mochila                        39
# Pandereta                      36
# Olla de presión                35
# Celular ABXY                   33
# Auriculares con micrófono      33
# dtype: int64 Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Pandereta                      58
# Guitarra acústica              58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Refrigerador                   49
# Silla de oficina               49
# Muñeca bebé                    48
# Vaso térmico                   47
# Cama box                       47
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Balón de voleibol              46
# Modelado predictivo            46
# Lavavajillas                   46
# Set de vasos                   46
# Kit de bancas                  45
# TV LED UHD 4K                  45
# Mochila                        45
# Mesa de centro                 45
# Cubo mágico 8x8                45
# Bicicleta                      45
# Ajedrez de madera              45
# Cama king                      45
# Sofá reclinable                44
# Mesa de noche                  44
# Olla de presión                44
# Auriculares con micrófono      44
# Tablet ABXY                    44
# Smartwatch                     44
# Dashboards con Power BI        43
# Ciencia de datos con Python    43
# Balón de baloncesto            42
# Dinosaurio Rex                 42
# Estufa                         42
# Celular ABXY                   41
# Smart TV                       40
# Cubertería                     39
# Asistente virtual              38
# Auriculares                    37
# Sillón                         35
# Impresora                      34
# Mesa de comedor                34
# Juego de mesa                  32
# dtype: int64 Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Modelado predictivo            53
# Cuerda para saltar             53
# Estufa                         53
# Carrito de control remoto      52
# Juego de mesa                  52
# Lavavajillas                   52
# Bicicleta                      52
# Pandereta                      51
# Balón de baloncesto            50
# Refrigerador                   50
# Impresora                      50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Olla de presión                47
# Sillón                         47
# Ajedrez de madera              47
# Guitarra acústica              47
# Smartwatch                     46
# Iphone 15                      46
# Silla de oficina               46
# Iniciando en programación      46
# Cama box                       46
# Ciencia de datos con Python    46
# Dinosaurio Rex                 46
# Sofá reclinable                45
# Secadora de ropa               45
# Celular ABXY                   44
# Cubo mágico 8x8                44
# Auriculares                    43
# Lavadora de ropa               42
# TV LED UHD 4K                  42
# Mesa de centro                 42
# Batería                        41
# Dashboards con Power BI        40
# Auriculares con micrófono      39
# Asistente virtual              39
# Muñeca bebé                    39
# Cubertería                     39
# Vaso térmico                   38
# Guitarra eléctrica             38
# Mochila                        36
# Microondas                     36
# Set de vasos                   36
# Bloques de construcción        35
# dtype: int64 Producto
# Cama box                       62
# Cubertería                     59
# Cama king                      56
# Dashboards con Power BI        56
# Carrito de control remoto      55
# Mesa de noche                  55
# Mesa de comedor                55
# Bloques de construcción        54
# Smart TV                       54
# Pandereta                      52
# Asistente virtual              50
# Balón de baloncesto            50
# Impresora                      50
# Set de ollas                   50
# Modelado predictivo            50
# Iphone 15                      48
# Balón de voleibol              48
# Batería                        48
# Juego de mesa                  48
# Muñeca bebé                    48
# Microondas                     48
# Vaso térmico                   48
# Cubo mágico 8x8                47
# Estufa                         47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# Set de vasos                   46
# Sillón                         45
# Tablet ABXY                    45
# Bicicleta                      45
# Auriculares                    44
# Mesa de centro                 44
# Mochila                        43
# Cuerda para saltar             43
# Lavavajillas                   43
# Iniciando en programación      43
# Auriculares con micrófono      42
# Kit de bancas                  42
# TV LED UHD 4K                  40
# Silla de oficina               40
# Secadora de ropa               40
# Celular ABXY                   39
# Ajedrez de madera              39
# Smartwatch                     39
# Lavadora de ropa               38
# Ciencia de datos con Python    38
# Refrigerador                   38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Data preparation
categories = product_counts_tienda.index  # Product categories['Artículos para el hogar', 'Deportes y diversión', ..]
counts = [product_counts_tienda.values, product_counts_tienda2.values, product_counts_tienda3.values, product_counts_tienda4.values]
data = pd.DataFrame(counts, index=store_labels, columns=categories)

plt.figure(figsize=(12, 6))
sns.heatmap(data, annot=True, cmap="coolwarm", fmt="d")
plt.title('Distribución de Ventas por Producto y Tienda')
plt.xlabel('Producto')
plt.ylabel('Tiendas')


plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
#OTRA FORMA DE SACAR EL PROMEDIO
average_shipping_tienda = tienda['Costo de envío'].mean()
average_shipping_tienda2 = tienda2['Costo de envío'].mean()
average_shipping_tienda3 = tienda3['Costo de envío'].mean()
average_shipping_tienda4 = tienda4['Costo de envío'].mean()

print(average_shipping_tienda, average_shipping_tienda2, average_shipping_tienda3, average_shipping_tienda4)
# Out:
# 26018.60958033065 25216.235693090293 24805.680373039424 23459.457167090754

# %%
import matplotlib.pyplot as plt
import numpy as np

data = [average_shipping_tienda, average_shipping_tienda2, average_shipping_tienda3, average_shipping_tienda4]

plt.figure() #Figura. Puede incluirse el tamaño con figsize
plt.plot(store_labels, data) #El gráfico
plt.title('Envío promedio por tienda') #El título
ax = plt.subplot() #Axis
ax.set_xticks(store_labels)  #Eje x
ax.set_xticklabels(store_labels) #Etiquetas del eje x
ax.set_xlabel('Tiendas')  #Nombre del eje x
ax.set_ylabel('Envíos')  #Nombre del eje y

plt.show()

# %% [markdown]
# # **INFORME FINAL**

# %% [markdown]
# > Agregar bloque entrecomillado
